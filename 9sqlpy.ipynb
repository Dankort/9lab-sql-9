# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /Users/danort/apps/anaconda3/lib/python3.11/site-packages (8.2.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in /Users/danort/apps/anaconda3/lib/python3.11/site-packages (from mysql-connector-python) (4.21.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
config = {
  'user': 'root',
  'password': 'Pantroams23',
  'host': 'localhost',
  'database': 'sakila'}

mydb = mysql.connector.connect(**config)

print("results 1")

cursor1 = mydb.cursor()

cursor1.execute("select  count(rm.rental_id) as rental_count, rm.customer_id, c.first_name, c.last_name from rental_may as rm left join customer as c on rm.customer_id = c.customer_id group by  customer_id")

myresults1 = cursor1.fetchall()

for x in myresults1:
    print(x)
    
print("end of results 1")
print("results 2")


cursor2 = mydb.cursor()

cursor2.execute("select  count(rj.rental_id) as rental_count, rj.customer_id, c.first_name, c.last_name from rental_june as rj left join customer as c on rj.customer_id = c.customer_id group by customer_id")

myresults2 = cursor2.fetchall()

for x in myresults2:
    print(x)
# Out:
# results 1
# (2, 1, 'MARY', 'SMITH')
# (1, 2, 'PATRICIA', 'JOHNSON')
# (2, 3, 'LINDA', 'WILLIAMS')
# (3, 5, 'ELIZABETH', 'BROWN')
# (3, 6, 'JENNIFER', 'DAVIS')
# (5, 7, 'MARIA', 'MILLER')
# (1, 8, 'SUSAN', 'WILSON')
# (3, 9, 'MARGARET', 'MOORE')
# (1, 10, 'DOROTHY', 'TAYLOR')
# (1, 11, 'LISA', 'ANDERSON')
# (2, 12, 'NANCY', 'THOMAS')
# (5, 14, 'BETTY', 'WHITE')
# (4, 16, 'SANDRA', 'MARTIN')
# (3, 17, 'DONNA', 'THOMPSON')
# (3, 18, 'CAROL', 'GARCIA')
# (6, 19, 'RUTH', 'MARTINEZ')
# (3, 20, 'SHARON', 'ROBINSON')
# (3, 21, 'MICHELLE', 'CLARK')
# (3, 22, 'LAURA', 'RODRIGUEZ')
# (3, 23, 'SARAH', 'LEWIS')
# (2, 24, 'KIMBERLY', 'LEE')
# (2, 25, 'DEBORAH', 'WALKER')
# (2, 26, 'JESSICA', 'HALL')
# (1, 27, 'SHIRLEY', 'ALLEN')
# (2, 28, 'CYNTHIA', 'YOUNG')
# (1, 29, 'ANGELA', 'HERNANDEZ')
# (3, 32, 'AMY', 'LOPEZ')
# (1, 33, 'ANNA', 'HILL')
# (2, 35, 'VIRGINIA', 'GREEN')
# (2, 36, 'KATHLEEN', 'ADAMS')
# (2, 37, 'PAMELA', 'BAKER')
# (1, 40, 'AMANDA', 'CARTER')
# (1, 42, 'CAROLYN', 'PEREZ')
# (2, 43, 'CHRISTINE', 'ROBERTS')
# (5, 44, 'MARIE', 'TURNER')
# (1, 45, 'JANET', 'PHILLIPS')
# (3, 46, 'CATHERINE', 'CAMPBELL')
# (3, 47, 'FRANCES', 'PARKER')
# (3, 48, 'ANN', 'EVANS')
# (4, 49, 'JOYCE', 'EDWARDS')
# (5, 50, 'DIANE', 'COLLINS')
# (3, 51, 'ALICE', 'STEWART')
# (1, 52, 'JULIE', 'SANCHEZ')
# (6, 53, 'HEATHER', 'MORRIS')
# (3, 54, 'TERESA', 'ROGERS')
# (3, 55, 'DORIS', 'REED')
# (4, 56, 'GLORIA', 'COOK')
# (2, 57, 'EVELYN', 'MORGAN')
# (3, 58, 'JEAN', 'BELL')
# (3, 59, 'CHERYL', 'MURPHY')
# (3, 60, 'MILDRED', 'BAILEY')
# (1, 61, 'KATHERINE', 'RIVERA')
# (2, 62, 'JOAN', 'COOPER')
# (3, 64, 'JUDITH', 'COX')
# (2, 65, 'ROSE', 'HOWARD')
# (1, 66, 'JANICE', 'WARD')
# (2, 67, 'KELLY', 'TORRES')
# (2, 69, 'JUDY', 'GRAY')
# (1, 70, 'CHRISTINA', 'RAMIREZ')
# (2, 71, 'KATHY', 'JAMES')
# (3, 72, 'THERESA', 'WATSON')
# (2, 73, 'BEVERLY', 'BROOKS')
# (1, 74, 'DENISE', 'KELLY')
# (2, 75, 'TAMMY', 'SANDERS')
# (2, 76, 'IRENE', 'PRICE')
# (5, 77, 'JANE', 'BENNETT')
# (3, 79, 'RACHEL', 'BARNES')
# (1, 81, 'ANDREA', 'HENDERSON')
# (2, 82, 'KATHRYN', 'COLEMAN')
# (3, 83, 'LOUISE', 'JENKINS')
# (3, 84, 'SARA', 'PERRY')
# (2, 85, 'ANNE', 'POWELL')
# (1, 86, 'JACQUELINE', 'LONG')
# (2, 87, 'WANDA', 'PATTERSON')
# (1, 88, 'BONNIE', 'HUGHES')
# (3, 89, 'JULIA', 'FLORES')
# (1, 91, 'LOIS', 'BUTLER')
# (2, 92, 'TINA', 'SIMMONS')
# (3, 93, 'PHYLLIS', 'FOSTER')
# (2, 94, 'NORMA', 'GONZALES')
# (1, 95, 'PAULA', 'BRYANT')
# (1, 98, 'LILLIAN', 'GRIFFIN')
# (1, 99, 'EMILY', 'DIAZ')
# (1, 100, 'ROBIN', 'HAYES')
# (1, 101, 'PEGGY', 'MYERS')
# (3, 102, 'CRYSTAL', 'FORD')
# (2, 103, 'GLADYS', 'HAMILTON')
# (2, 104, 'RITA', 'GRAHAM')
# (4, 105, 'DAWN', 'SULLIVAN')
# (2, 106, 'CONNIE', 'WALLACE')
# (2, 107, 'FLORENCE', 'WOODS')
# (2, 108, 'TRACY', 'COLE')
# (7, 109, 'EDNA', 'WEST')
# (2, 110, 'TIFFANY', 'JORDAN')
# (1, 111, 'CARMEN', 'OWENS')
# (2, 112, 'ROSA', 'REYNOLDS')
# (2, 113, 'CINDY', 'FISHER')
# (3, 114, 'GRACE', 'ELLIS')
# (3, 115, 'WENDY', 'HARRISON')
# (1, 116, 'VICTORIA', 'GIBSON')
# (2, 117, 'EDITH', 'MCDONALD')
# (1, 118, 'KIM', 'CRUZ')
# (3, 119, 'SHERRY', 'MARSHALL')
# (2, 120, 'SYLVIA', 'ORTIZ')
# (1, 121, 'JOSEPHINE', 'GOMEZ')
# (2, 122, 'THELMA', 'MURRAY')
# (1, 123, 'SHANNON', 'FREEMAN')
# (4, 124, 'SHEILA', 'WELLS')
# (1, 125, 'ETHEL', 'WEBB')
# (3, 126, 'ELLEN', 'SIMPSON')
# (2, 127, 'ELAINE', 'STEVENS')
# (2, 128, 'MARJORIE', 'TUCKER')
# (2, 130, 'CHARLOTTE', 'HUNTER')
# (3, 131, 'MONICA', 'HICKS')
# (2, 133, 'PAULINE', 'HENRY')
# (4, 134, 'EMMA', 'BOYD')
# (2, 135, 'JUANITA', 'MASON')
# (1, 136, 'ANITA', 'MORALES')
# (1, 137, 'RHONDA', 'KENNEDY')
# (2, 138, 'HAZEL', 'WARREN')
# (1, 141, 'DEBBIE', 'REYES')
# (3, 142, 'APRIL', 'BURNS')
# (2, 143, 'LESLIE', 'GORDON')
# (2, 144, 'CLARA', 'SHAW')
# (1, 145, 'LUCILLE', 'HOLMES')
# (2, 146, 'JAMIE', 'RICE')
# (2, 147, 'JOANNE', 'ROBERTSON')
# (1, 148, 'ELEANOR', 'HUNT')
# (1, 149, 'VALERIE', 'BLACK')
# (3, 150, 'DANIELLE', 'DANIELS')
# (2, 151, 'MEGAN', 'PALMER')
# (2, 152, 'ALICIA', 'MILLS')
# (3, 154, 'MICHELE', 'GRANT')
# (1, 155, 'GAIL', 'KNIGHT')
# (2, 156, 'BERTHA', 'FERGUSON')
# (2, 157, 'DARLENE', 'ROSE')
# (2, 158, 'VERONICA', 'STONE')
# (4, 159, 'JILL', 'HAWKINS')
# (6, 161, 'GERALDINE', 'PERKINS')
# (3, 162, 'LAUREN', 'HUDSON')
# (1, 164, 'JOANN', 'GARDNER')
# (1, 165, 'LORRAINE', 'STEPHENS')
# (1, 166, 'LYNN', 'PAYNE')
# (3, 167, 'SALLY', 'PIERCE')
# (2, 168, 'REGINA', 'BERRY')
# (2, 169, 'ERICA', 'MATTHEWS')
# (3, 170, 'BEATRICE', 'ARNOLD')
# (1, 171, 'DOLORES', 'WAGNER')
# (3, 172, 'BERNICE', 'WILLIS')
# (2, 173, 'AUDREY', 'RAY')
# (2, 174, 'YVONNE', 'WATKINS')
# (5, 176, 'JUNE', 'CARROLL')
# (3, 179, 'DANA', 'HART')
# (1, 180, 'STACY', 'CUNNINGHAM')
# (1, 181, 'ANA', 'BRADLEY')
# (2, 182, 'RENEE', 'LANE')
# (1, 183, 'IDA', 'ANDREWS')
# (3, 184, 'VIVIAN', 'RUIZ')
# (3, 185, 'ROBERTA', 'HARPER')
# (2, 186, 'HOLLY', 'FOX')
# (1, 187, 'BRITTANY', 'RILEY')
# (1, 189, 'LORETTA', 'CARPENTER')
# (2, 190, 'YOLANDA', 'WEAVER')
# (2, 191, 'JEANETTE', 'GREENE')
# (1, 192, 'LAURIE', 'LAWRENCE')
# (2, 193, 'KATIE', 'ELLIOTT')
# (2, 194, 'KRISTEN', 'CHAVEZ')
# (4, 196, 'ALMA', 'AUSTIN')
# (8, 197, 'SUE', 'PETERS')
# (5, 198, 'ELSIE', 'KELLEY')
# (1, 199, 'BETH', 'FRANKLIN')
# (1, 200, 'JEANNE', 'LAWSON')
# (3, 201, 'VICKI', 'FIELDS')
# (1, 203, 'TARA', 'RYAN')
# (4, 204, 'ROSEMARY', 'SCHMIDT')
# (6, 207, 'GERTRUDE', 'CASTILLO')
# (1, 208, 'LUCY', 'WHEELER')
# (3, 209, 'TONYA', 'CHAPMAN')
# (1, 210, 'ELLA', 'OLIVER')
# (1, 211, 'STACEY', 'MONTGOMERY')
# (1, 213, 'GINA', 'WILLIAMSON')
# (5, 214, 'KRISTIN', 'JOHNSTON')
# (2, 215, 'JESSIE', 'BANKS')
# (1, 216, 'NATALIE', 'MEYER')
# (2, 217, 'AGNES', 'BISHOP')
# (1, 219, 'WILLIE', 'HOWELL')
# (2, 220, 'CHARLENE', 'ALVAREZ')
# (1, 221, 'BESSIE', 'MORRISON')
# (5, 222, 'DELORES', 'HANSEN')
# (1, 223, 'MELINDA', 'FERNANDEZ')
# (2, 225, 'ARLENE', 'HARVEY')
# (2, 227, 'COLLEEN', 'BURTON')
# (2, 228, 'ALLISON', 'STANLEY')
# (2, 230, 'JOY', 'GEORGE')
# (3, 231, 'GEORGIA', 'JACOBS')
# (2, 232, 'CONSTANCE', 'REID')
# (1, 234, 'CLAUDIA', 'FULLER')
# (2, 235, 'JACKIE', 'LYNCH')
# (3, 236, 'MARCIA', 'DEAN')
# (2, 237, 'TANYA', 'GILBERT')
# (2, 238, 'NELLIE', 'GARRETT')
# (6, 239, 'MINNIE', 'ROMERO')
# (3, 240, 'MARLENE', 'WELCH')
# (2, 241, 'HEIDI', 'LARSON')
# (3, 242, 'GLENDA', 'FRAZIER')
# (1, 243, 'LYDIA', 'BURKE')
# (2, 244, 'VIOLA', 'HANSON')
# (6, 245, 'COURTNEY', 'DAY')
# (5, 246, 'MARIAN', 'MENDOZA')
# (3, 247, 'STELLA', 'MORENO')
# (2, 248, 'CAROLINE', 'BOWMAN')
# (4, 249, 'DORA', 'MEDINA')
# (5, 250, 'JO', 'FOWLER')
# (6, 251, 'VICKIE', 'BREWER')
# (2, 252, 'MATTIE', 'HOFFMAN')
# (3, 253, 'TERRY', 'CARLSON')
# (2, 254, 'MAXINE', 'SILVA')
# (5, 256, 'MABEL', 'HOLLAND')
# (3, 257, 'MARSHA', 'DOUGLAS')
# (3, 259, 'LENA', 'JENSEN')
# (1, 260, 'CHRISTY', 'VARGAS')
# (4, 261, 'DEANNA', 'BYRD')
# (1, 262, 'PATSY', 'DAVIDSON')
# (2, 263, 'HILDA', 'HOPKINS')
# (1, 265, 'JENNIE', 'TERRY')
# (2, 266, 'NORA', 'HERRERA')
# (3, 267, 'MARGIE', 'WADE')
# (6, 269, 'CASSANDRA', 'WALTERS')
# (2, 270, 'LEAH', 'CURTIS')
# (1, 271, 'PENNY', 'NEAL')
# (4, 272, 'KAY', 'CALDWELL')
# (2, 273, 'PRISCILLA', 'LOWE')
# (6, 274, 'NAOMI', 'JENNINGS')
# (1, 275, 'CAROLE', 'BARNETT')
# (2, 276, 'BRANDY', 'GRAVES')
# (1, 277, 'OLGA', 'JIMENEZ')
# (1, 278, 'BILLIE', 'HORTON')
# (2, 279, 'DIANNE', 'SHELTON')
# (1, 280, 'TRACEY', 'BARRETT')
# (2, 281, 'LEONA', 'OBRIEN')
# (3, 282, 'JENNY', 'CASTRO')
# (3, 284, 'SONIA', 'GREGORY')
# (1, 286, 'VELMA', 'LUCAS')
# (3, 287, 'BECKY', 'MILES')
# (4, 288, 'BOBBIE', 'CRAIG')
# (1, 290, 'KRISTINA', 'CHAMBERS')
# (3, 291, 'TONI', 'HOLT')
# (1, 292, 'MISTY', 'LAMBERT')
# (3, 293, 'MAE', 'FLETCHER')
# (1, 294, 'SHELLY', 'WATTS')
# (1, 295, 'DAISY', 'BATES')
# (4, 296, 'RAMONA', 'HALE')
# (2, 297, 'SHERRI', 'RHODES')
# (1, 298, 'ERIKA', 'PENA')
# (2, 299, 'JAMES', 'GANNON')
# (3, 300, 'JOHN', 'FARNSWORTH')
# (3, 301, 'ROBERT', 'BAUGHMAN')
# (2, 302, 'MICHAEL', 'SILVERMAN')
# (3, 303, 'WILLIAM', 'SATTERFIELD')
# (3, 304, 'DAVID', 'ROYAL')
# (1, 305, 'RICHARD', 'MCCRARY')
# (2, 306, 'CHARLES', 'KOWALSKI')
# (4, 307, 'JOSEPH', 'JOY')
# (1, 308, 'THOMAS', 'GRIGSBY')
# (2, 309, 'CHRISTOPHER', 'GRECO')
# (1, 310, 'DANIEL', 'CABRAL')
# (5, 311, 'PAUL', 'TROUT')
# (4, 312, 'MARK', 'RINEHART')
# (4, 313, 'DONALD', 'MAHON')
# (2, 314, 'GEORGE', 'LINTON')
# (2, 315, 'KENNETH', 'GOODEN')
# (3, 316, 'STEVEN', 'CURLEY')
# (1, 317, 'EDWARD', 'BAUGH')
# (1, 318, 'BRIAN', 'WYMAN')
# (3, 319, 'RONALD', 'WEINER')
# (3, 321, 'KEVIN', 'SCHULER')
# (2, 322, 'JASON', 'MORRISSEY')
# (3, 323, 'MATTHEW', 'MAHAN')
# (1, 324, 'GARY', 'COY')
# (1, 325, 'TIMOTHY', 'BUNN')
# (3, 326, 'JOSE', 'ANDREW')
# (1, 327, 'LARRY', 'THRASHER')
# (1, 328, 'JEFFREY', 'SPEAR')
# (2, 330, 'SCOTT', 'SHELLEY')
# (2, 331, 'ERIC', 'ROBERT')
# (2, 332, 'STEPHEN', 'QUALLS')
# (1, 333, 'ANDREW', 'PURDY')
# (2, 334, 'RAYMOND', 'MCWHORTER')
# (3, 337, 'JERRY', 'JORDON')
# (1, 338, 'DENNIS', 'GILMAN')
# (1, 339, 'WALTER', 'PERRYMAN')
# (2, 343, 'DOUGLAS', 'GRAF')
# (2, 344, 'HENRY', 'BILLINGSLEY')
# (2, 345, 'CARL', 'ARTIS')
# (2, 346, 'ARTHUR', 'SIMPKINS')
# (2, 348, 'ROGER', 'QUINTANILLA')
# (1, 349, 'JOE', 'GILLILAND')
# (2, 350, 'JUAN', 'FRALEY')
# (1, 351, 'JACK', 'FOUST')
# (1, 352, 'ALBERT', 'CROUSE')
# (1, 353, 'JONATHAN', 'SCARBOROUGH')
# (3, 354, 'JUSTIN', 'NGO')
# (1, 355, 'TERRY', 'GRISSOM')
# (1, 356, 'GERALD', 'FULTZ')
# (3, 357, 'KEITH', 'RICO')
# (1, 358, 'SAMUEL', 'MARLOW')
# (3, 359, 'WILLIE', 'MARKHAM')
# (2, 360, 'RALPH', 'MADRIGAL')
# (2, 361, 'LAWRENCE', 'LAWTON')
# (1, 362, 'NICHOLAS', 'BARFIELD')
# (1, 363, 'ROY', 'WHITING')
# (1, 364, 'BENJAMIN', 'VARNEY')
# (2, 365, 'BRUCE', 'SCHWARZ')
# (1, 366, 'BRANDON', 'HUEY')
# (2, 367, 'ADAM', 'GOOCH')
# (4, 368, 'HARRY', 'ARCE')
# (4, 369, 'FRED', 'WHEAT')
# (6, 371, 'BILLY', 'POULIN')
# (2, 372, 'STEVE', 'MACKENZIE')
# (1, 373, 'LOUIS', 'LEONE')
# (3, 374, 'JEREMY', 'HURTADO')
# (4, 375, 'AARON', 'SELBY')
# (1, 376, 'RANDY', 'GAITHER')
# (1, 378, 'EUGENE', 'CULPEPPER')
# (2, 379, 'CARLOS', 'COUGHLIN')
# (1, 380, 'RUSSELL', 'BRINSON')
# (3, 381, 'BOBBY', 'BOUDREAU')
# (2, 382, 'VICTOR', 'BARKLEY')
# (2, 383, 'MARTIN', 'BALES')
# (4, 384, 'ERNEST', 'STEPP')
# (2, 385, 'PHILLIP', 'HOLM')
# (1, 386, 'TODD', 'TAN')
# (4, 387, 'JESSE', 'SCHILLING')
# (2, 388, 'CRAIG', 'MORRELL')
# (1, 389, 'ALAN', 'KAHN')
# (2, 390, 'SHAWN', 'HEATON')
# (5, 391, 'CLARENCE', 'GAMEZ')
# (2, 393, 'PHILIP', 'CAUSEY')
# (2, 394, 'CHRIS', 'BROTHERS')
# (1, 396, 'EARL', 'SHANKS')
# (1, 397, 'JIMMY', 'SCHRADER')
# (1, 398, 'ANTONIO', 'MEEK')
# (3, 399, 'DANNY', 'ISOM')
# (4, 400, 'BRYAN', 'HARDISON')
# (3, 401, 'TONY', 'CARRANZA')
# (1, 402, 'LUIS', 'YANEZ')
# (2, 403, 'MIKE', 'WAY')
# (1, 404, 'STANLEY', 'SCROGGINS')
# (2, 405, 'LEONARD', 'SCHOFIELD')
# (1, 406, 'NATHAN', 'RUNYON')
# (1, 407, 'DALE', 'RATCLIFF')
# (3, 408, 'MANUEL', 'MURRELL')
# (1, 409, 'RODNEY', 'MOELLER')
# (2, 411, 'NORMAN', 'CURRIER')
# (4, 412, 'ALLEN', 'BUTTERFIELD')
# (2, 413, 'MARVIN', 'YEE')
# (2, 414, 'VINCENT', 'RALSTON')
# (1, 415, 'GLENN', 'PULLEN')
# (3, 416, 'JEFFERY', 'PINSON')
# (3, 417, 'TRAVIS', 'ESTEP')
# (1, 419, 'CHAD', 'CARBONE')
# (1, 420, 'JACOB', 'LANCE')
# (2, 421, 'LEE', 'HAWKS')
# (1, 422, 'MELVIN', 'ELLINGTON')
# (1, 424, 'KYLE', 'SPURLOCK')
# (1, 425, 'FRANCIS', 'SIKES')
# (1, 426, 'BRADLEY', 'MOTLEY')
# (1, 427, 'JESUS', 'MCCARTNEY')
# (1, 428, 'HERBERT', 'KRUGER')
# (5, 429, 'FREDERICK', 'ISBELL')
# (2, 430, 'RAY', 'HOULE')
# (1, 431, 'JOEL', 'FRANCISCO')
# (3, 432, 'EDWIN', 'BURK')
# (2, 433, 'DON', 'BONE')
# (1, 434, 'EDDIE', 'TOMLIN')
# (2, 435, 'RICKY', 'SHELBY')
# (3, 436, 'TROY', 'QUIGLEY')
# (3, 437, 'RANDALL', 'NEUMANN')
# (3, 438, 'BARRY', 'LOVELACE')
# (3, 439, 'ALEXANDER', 'FENNELL')
# (1, 440, 'BERNARD', 'COLBY')
# (1, 441, 'MARIO', 'CHEATHAM')
# (3, 442, 'LEROY', 'BUSTAMANTE')
# (1, 443, 'FRANCISCO', 'SKIDMORE')
# (2, 444, 'MARCUS', 'HIDALGO')
# (2, 445, 'MICHEAL', 'FORMAN')
# (3, 446, 'THEODORE', 'CULP')
# (2, 447, 'CLIFFORD', 'BOWENS')
# (2, 448, 'MIGUEL', 'BETANCOURT')
# (3, 449, 'OSCAR', 'AQUINO')
# (1, 450, 'JAY', 'ROBB')
# (3, 451, 'JIM', 'REA')
# (3, 452, 'TOM', 'MILNER')
# (1, 454, 'ALEX', 'GRESHAM')
# (2, 455, 'JON', 'WILES')
# (1, 456, 'RONNIE', 'RICKETTS')
# (1, 457, 'BILL', 'GAVIN')
# (1, 459, 'TOMMY', 'COLLAZO')
# (4, 460, 'LEON', 'BOSTIC')
# (1, 461, 'DEREK', 'BLAKELY')
# (2, 462, 'WARREN', 'SHERROD')
# (1, 463, 'DARRELL', 'POWER')
# (2, 464, 'JEROME', 'KENYON')
# (1, 465, 'FLOYD', 'GANDY')
# (1, 466, 'LEO', 'EBERT')
# (1, 467, 'ALVIN', 'DELOACH')
# (5, 468, 'TIM', 'CARY')
# (5, 469, 'WESLEY', 'BULL')
# (1, 470, 'GORDON', 'ALLARD')
# (1, 471, 'DEAN', 'SAUER')
# (4, 472, 'GREG', 'ROBINS')
# (3, 473, 'JORGE', 'OLIVARES')
# (1, 474, 'DUSTIN', 'GILLETTE')
# (2, 475, 'PEDRO', 'CHESTNUT')
# (2, 476, 'DERRICK', 'BOURQUE')
# (1, 477, 'DAN', 'PAINE')
# (2, 479, 'ZACHARY', 'HITE')
# (3, 480, 'COREY', 'HAUSER')
# (1, 481, 'HERMAN', 'DEVORE')
# (3, 482, 'MAURICE', 'CRAWLEY')
# (1, 483, 'VERNON', 'CHAPA')
# (3, 484, 'ROBERTO', 'VU')
# (1, 485, 'CLYDE', 'TOBIAS')
# (3, 486, 'GLEN', 'TALBERT')
# (2, 489, 'RICARDO', 'MEADOR')
# (2, 490, 'SAM', 'MCDUFFIE')
# (2, 491, 'RICK', 'MATTOX')
# (1, 492, 'LESTER', 'KRAUS')
# (1, 493, 'BRENT', 'HARKINS')
# (1, 494, 'RAMON', 'CHOATE')
# (2, 495, 'CHARLIE', 'BESS')
# (2, 496, 'TYLER', 'WREN')
# (1, 497, 'GILBERT', 'SLEDGE')
# (3, 498, 'GENE', 'SANBORN')
# (1, 499, 'MARC', 'OUTLAW')
# (3, 500, 'REGINALD', 'KINDER')
# (2, 501, 'RUBEN', 'GEARY')
# (4, 502, 'BRETT', 'CORNWELL')
# (4, 503, 'ANGEL', 'BARCLAY')
# (3, 504, 'NATHANIEL', 'ADAM')
# (2, 505, 'RAFAEL', 'ABNEY')
# (7, 506, 'LESLIE', 'SEWARD')
# (2, 507, 'EDGAR', 'RHOADS')
# (2, 508, 'MILTON', 'HOWLAND')
# (2, 509, 'RAUL', 'FORTIER')
# (3, 510, 'BEN', 'EASTER')
# (2, 511, 'CHESTER', 'BENNER')
# (1, 513, 'DUANE', 'TUBBS')
# (1, 514, 'FRANKLIN', 'TROUTMAN')
# (2, 515, 'ANDRE', 'RAPP')
# (2, 516, 'ELMER', 'NOE')
# (1, 517, 'BRAD', 'MCCURDY')
# (1, 518, 'GABRIEL', 'HARDER')
# (1, 519, 'RON', 'DELUCA')
# (1, 520, 'MITCHELL', 'WESTMORELAND')
# (1, 522, 'ARNOLD', 'HAVENS')
# (2, 523, 'HARVEY', 'GUAJARDO')
# (2, 524, 'JARED', 'ELY')
# (1, 525, 'ADRIAN', 'CLARY')
# (3, 526, 'KARL', 'SEAL')
# (5, 528, 'CLAUDE', 'HERZOG')
# (1, 529, 'ERIK', 'GUILLEN')
# (1, 530, 'DARRYL', 'ASHCRAFT')
# (2, 531, 'JAMIE', 'WAUGH')
# (1, 532, 'NEIL', 'RENNER')
# (3, 533, 'JESSIE', 'MILAM')
# (2, 534, 'CHRISTIAN', 'JUNG')
# (4, 535, 'JAVIER', 'ELROD')
# (2, 536, 'FERNANDO', 'CHURCHILL')
# (1, 537, 'CLINTON', 'BUFORD')
# (2, 538, 'TED', 'BREAUX')
# (2, 539, 'MATHEW', 'BOLIN')
# (2, 541, 'DARREN', 'WINDHAM')
# (2, 542, 'LONNIE', 'TIRADO')
# (2, 543, 'LANCE', 'PEMBERTON')
# (2, 544, 'CODY', 'NOLEN')
# (2, 545, 'JULIO', 'NOLAND')
# (2, 546, 'KELLY', 'KNOTT')
# (3, 547, 'KURT', 'EMMONS')
# (3, 548, 'ALLAN', 'CORNISH')
# (4, 549, 'NELSON', 'CHRISTENSON')
# (1, 550, 'GUY', 'BROWNLEE')
# (5, 551, 'CLAYTON', 'BARBEE')
# (1, 552, 'HUGH', 'WALDROP')
# (1, 553, 'MAX', 'PITT')
# (2, 554, 'DWAYNE', 'OLVERA')
# (3, 556, 'ARMANDO', 'GRUBER')
# (2, 557, 'FELIX', 'GAFFNEY')
# (1, 560, 'JORDAN', 'ARCHULETA')
# (2, 561, 'IAN', 'STILL')
# (3, 562, 'WALLACE', 'SLONE')
# (2, 563, 'KEN', 'PREWITT')
# (2, 564, 'BOB', 'PFEIFFER')
# (2, 565, 'JAIME', 'NETTLES')
# (2, 566, 'CASEY', 'MENA')
# (5, 569, 'DAVE', 'GARDINER')
# (1, 570, 'IVAN', 'CROMWELL')
# (2, 571, 'JOHNNIE', 'CHISHOLM')
# (1, 572, 'SIDNEY', 'BURLESON')
# (1, 573, 'BYRON', 'BOX')
# (1, 574, 'JULIAN', 'VEST')
# (5, 575, 'ISAAC', 'OGLESBY')
# (2, 576, 'MORRIS', 'MCCARTER')
# (1, 577, 'CLIFTON', 'MALCOLM')
# (1, 578, 'WILLARD', 'LUMPKIN')
# (1, 580, 'ROSS', 'GREY')
# (2, 581, 'VIRGIL', 'WOFFORD')
# (1, 582, 'ANDY', 'VANHORN')
# (3, 584, 'SALVADOR', 'TEEL')
# (2, 586, 'KIRK', 'STCLAIR')
# (2, 587, 'SERGIO', 'STANFIELD')
# (2, 588, 'MARION', 'OCAMPO')
# (3, 589, 'TRACY', 'HERRMANN')
# (1, 590, 'SETH', 'HANNON')
# (2, 593, 'RENE', 'MCALISTER')
# (4, 594, 'EDUARDO', 'HIATT')
# (1, 595, 'TERRENCE', 'GUNDERSON')
# (6, 596, 'ENRIQUE', 'FORSYTHE')
# (2, 597, 'FREDDIE', 'DUGGAN')
# (1, 599, 'AUSTIN', 'CINTRON')
# end of results 1
# results 2
# (28, 1, 'MARY', 'SMITH')
# (4, 2, 'PATRICIA', 'JOHNSON')
# (16, 3, 'LINDA', 'WILLIAMS')
# (24, 4, 'BARBARA', 'JONES')
# (20, 5, 'ELIZABETH', 'BROWN')
# (16, 6, 'JENNIFER', 'DAVIS')
# (20, 7, 'MARIA', 'MILLER')
# (12, 8, 'SUSAN', 'WILSON')
# (8, 9, 'MARGARET', 'MOORE')
# (20, 10, 'DOROTHY', 'TAYLOR')
# (12, 11, 'LISA', 'ANDERSON')
# (24, 12, 'NANCY', 'THOMAS')
# (16, 13, 'KAREN', 'JACKSON')
# (4, 14, 'BETTY', 'WHITE')
# (12, 15, 'HELEN', 'HARRIS')
# (16, 16, 'SANDRA', 'MARTIN')
# (12, 17, 'DONNA', 'THOMPSON')
# (16, 18, 'CAROL', 'GARCIA')
# (12, 19, 'RUTH', 'MARTINEZ')
# (16, 20, 'SHARON', 'ROBINSON')
# (20, 21, 'MICHELLE', 'CLARK')
# (4, 22, 'LAURA', 'RODRIGUEZ')
# (20, 23, 'SARAH', 'LEWIS')
# (20, 24, 'KIMBERLY', 'LEE')
# (24, 25, 'DEBORAH', 'WALKER')
# (28, 26, 'JESSICA', 'HALL')
# (32, 27, 'SHIRLEY', 'ALLEN')
# (20, 28, 'CYNTHIA', 'YOUNG')
# (28, 29, 'ANGELA', 'HERNANDEZ')
# (16, 30, 'MELISSA', 'KING')
# (44, 31, 'BRENDA', 'WRIGHT')
# (16, 32, 'AMY', 'LOPEZ')
# (8, 33, 'ANNA', 'HILL')
# (12, 34, 'REBECCA', 'SCOTT')
# (24, 35, 'VIRGINIA', 'GREEN')
# (4, 36, 'KATHLEEN', 'ADAMS')
# (12, 37, 'PAMELA', 'BAKER')
# (20, 38, 'MARTHA', 'GONZALEZ')
# (24, 39, 'DEBRA', 'NELSON')
# (16, 40, 'AMANDA', 'CARTER')
# (8, 41, 'STEPHANIE', 'MITCHELL')
# (16, 42, 'CAROLYN', 'PEREZ')
# (4, 43, 'CHRISTINE', 'ROBERTS')
# (16, 44, 'MARIE', 'TURNER')
# (20, 45, 'JANET', 'PHILLIPS')
# (28, 46, 'CATHERINE', 'CAMPBELL')
# (12, 47, 'FRANCES', 'PARKER')
# (8, 48, 'ANN', 'EVANS')
# (20, 49, 'JOYCE', 'EDWARDS')
# (16, 50, 'DIANE', 'COLLINS')
# (8, 51, 'ALICE', 'STEWART')
# (16, 52, 'JULIE', 'SANCHEZ')
# (20, 53, 'HEATHER', 'MORRIS')
# (16, 54, 'TERESA', 'ROGERS')
# (20, 55, 'DORIS', 'REED')
# (16, 56, 'GLORIA', 'COOK')
# (20, 57, 'EVELYN', 'MORGAN')
# (12, 58, 'JEAN', 'BELL')
# (12, 59, 'CHERYL', 'MURPHY')
# (8, 60, 'MILDRED', 'BAILEY')
# (28, 62, 'JOAN', 'COOPER')
# (4, 63, 'ASHLEY', 'RICHARDSON')
# (8, 64, 'JUDITH', 'COX')
# (8, 65, 'ROSE', 'HOWARD')
# (28, 66, 'JANICE', 'WARD')
# (16, 67, 'KELLY', 'TORRES')
# (20, 68, 'NICOLE', 'PETERSON')
# (8, 69, 'JUDY', 'GRAY')
# (4, 70, 'CHRISTINA', 'RAMIREZ')
# (12, 71, 'KATHY', 'JAMES')
# (4, 72, 'THERESA', 'WATSON')
# (8, 73, 'BEVERLY', 'BROOKS')
# (16, 74, 'DENISE', 'KELLY')
# (20, 75, 'TAMMY', 'SANDERS')
# (24, 76, 'IRENE', 'PRICE')
# (20, 77, 'JANE', 'BENNETT')
# (12, 78, 'LORI', 'WOOD')
# (8, 79, 'RACHEL', 'BARNES')
# (12, 80, 'MARILYN', 'ROSS')
# (12, 81, 'ANDREA', 'HENDERSON')
# (20, 82, 'KATHRYN', 'COLEMAN')
# (16, 83, 'LOUISE', 'JENKINS')
# (24, 84, 'SARA', 'PERRY')
# (24, 85, 'ANNE', 'POWELL')
# (28, 86, 'JACQUELINE', 'LONG')
# (20, 87, 'WANDA', 'PATTERSON')
# (12, 88, 'BONNIE', 'HUGHES')
# (20, 89, 'JULIA', 'FLORES')
# (12, 90, 'RUBY', 'WASHINGTON')
# (16, 91, 'LOIS', 'BUTLER')
# (12, 92, 'TINA', 'SIMMONS')
# (8, 93, 'PHYLLIS', 'FOSTER')
# (20, 94, 'NORMA', 'GONZALES')
# (16, 95, 'PAULA', 'BRYANT')
# (28, 96, 'DIANA', 'ALEXANDER')
# (12, 97, 'ANNIE', 'RUSSELL')
# (24, 98, 'LILLIAN', 'GRIFFIN')
# (8, 99, 'EMILY', 'DIAZ')
# (16, 100, 'ROBIN', 'HAYES')
# (8, 102, 'CRYSTAL', 'FORD')
# (16, 103, 'GLADYS', 'HAMILTON')
# (16, 104, 'RITA', 'GRAHAM')
# (12, 105, 'DAWN', 'SULLIVAN')
# (8, 106, 'CONNIE', 'WALLACE')
# (28, 107, 'FLORENCE', 'WOODS')
# (20, 108, 'TRACY', 'COLE')
# (20, 109, 'EDNA', 'WEST')
# (4, 110, 'TIFFANY', 'JORDAN')
# (24, 111, 'CARMEN', 'OWENS')
# (16, 112, 'ROSA', 'REYNOLDS')
# (24, 113, 'CINDY', 'FISHER')
# (16, 114, 'GRACE', 'ELLIS')
# (12, 115, 'WENDY', 'HARRISON')
# (24, 116, 'VICTORIA', 'GIBSON')
# (8, 117, 'EDITH', 'MCDONALD')
# (12, 118, 'KIM', 'CRUZ')
# (12, 119, 'SHERRY', 'MARSHALL')
# (24, 120, 'SYLVIA', 'ORTIZ')
# (8, 121, 'JOSEPHINE', 'GOMEZ')
# (28, 122, 'THELMA', 'MURRAY')
# (20, 123, 'SHANNON', 'FREEMAN')
# (4, 124, 'SHEILA', 'WELLS')
# (16, 125, 'ETHEL', 'WEBB')
# (4, 126, 'ELLEN', 'SIMPSON')
# (12, 127, 'ELAINE', 'STEVENS')
# (8, 128, 'MARJORIE', 'TUCKER')
# (24, 129, 'CARRIE', 'PORTER')
# (24, 130, 'CHARLOTTE', 'HUNTER')
# (8, 131, 'MONICA', 'HICKS')
# (24, 132, 'ESTHER', 'CRAWFORD')
# (16, 133, 'PAULINE', 'HENRY')
# (16, 134, 'EMMA', 'BOYD')
# (12, 135, 'JUANITA', 'MASON')
# (4, 136, 'ANITA', 'MORALES')
# (16, 137, 'RHONDA', 'KENNEDY')
# (12, 138, 'HAZEL', 'WARREN')
# (16, 139, 'AMBER', 'DIXON')
# (16, 140, 'EVA', 'RAMOS')
# (12, 141, 'DEBBIE', 'REYES')
# (8, 142, 'APRIL', 'BURNS')
# (20, 143, 'LESLIE', 'GORDON')
# (24, 144, 'CLARA', 'SHAW')
# (8, 145, 'LUCILLE', 'HOLMES')
# (28, 146, 'JAMIE', 'RICE')
# (16, 147, 'JOANNE', 'ROBERTSON')
# (20, 148, 'ELEANOR', 'HUNT')
# (28, 149, 'VALERIE', 'BLACK')
# (8, 150, 'DANIELLE', 'DANIELS')
# (20, 151, 'MEGAN', 'PALMER')
# (4, 152, 'ALICIA', 'MILLS')
# (16, 153, 'SUZANNE', 'NICHOLS')
# (12, 154, 'MICHELE', 'GRANT')
# (20, 155, 'GAIL', 'KNIGHT')
# (16, 156, 'BERTHA', 'FERGUSON')
# (4, 157, 'DARLENE', 'ROSE')
# (16, 158, 'VERONICA', 'STONE')
# (8, 159, 'JILL', 'HAWKINS')
# (12, 160, 'ERIN', 'DUNN')
# (8, 161, 'GERALDINE', 'PERKINS')
# (20, 162, 'LAUREN', 'HUDSON')
# (24, 163, 'CATHY', 'SPENCER')
# (12, 164, 'JOANN', 'GARDNER')
# (8, 165, 'LORRAINE', 'STEPHENS')
# (16, 166, 'LYNN', 'PAYNE')
# (12, 167, 'SALLY', 'PIERCE')
# (4, 168, 'REGINA', 'BERRY')
# (8, 169, 'ERICA', 'MATTHEWS')
# (8, 170, 'BEATRICE', 'ARNOLD')
# (28, 171, 'DOLORES', 'WAGNER')
# (12, 172, 'BERNICE', 'WILLIS')
# (20, 173, 'AUDREY', 'RAY')
# (16, 174, 'YVONNE', 'WATKINS')
# (8, 175, 'ANNETTE', 'OLSON')
# (32, 176, 'JUNE', 'CARROLL')
# (20, 177, 'SAMANTHA', 'DUNCAN')
# (32, 178, 'MARION', 'SNYDER')
# (8, 179, 'DANA', 'HART')
# (8, 180, 'STACY', 'CUNNINGHAM')
# (16, 181, 'ANA', 'BRADLEY')
# (16, 182, 'RENEE', 'LANE')
# (16, 183, 'IDA', 'ANDREWS')
# (8, 184, 'VIVIAN', 'RUIZ')
# (12, 185, 'ROBERTA', 'HARPER')
# (24, 186, 'HOLLY', 'FOX')
# (28, 187, 'BRITTANY', 'RILEY')
# (16, 188, 'MELANIE', 'ARMSTRONG')
# (20, 189, 'LORETTA', 'CARPENTER')
# (20, 190, 'YOLANDA', 'WEAVER')
# (24, 191, 'JEANETTE', 'GREENE')
# (4, 192, 'LAURIE', 'LAWRENCE')
# (24, 193, 'KATIE', 'ELLIOTT')
# (20, 194, 'KRISTEN', 'CHAVEZ')
# (32, 196, 'ALMA', 'AUSTIN')
# (32, 197, 'SUE', 'PETERS')
# (4, 198, 'ELSIE', 'KELLEY')
# (12, 199, 'BETH', 'FRANKLIN')
# (28, 200, 'JEANNE', 'LAWSON')
# (20, 201, 'VICKI', 'FIELDS')
# (16, 202, 'CARLA', 'GUTIERREZ')
# (16, 203, 'TARA', 'RYAN')
# (24, 204, 'ROSEMARY', 'SCHMIDT')
# (16, 205, 'EILEEN', 'CARR')
# (12, 206, 'TERRI', 'VASQUEZ')
# (4, 207, 'GERTRUDE', 'CASTILLO')
# (20, 208, 'LUCY', 'WHEELER')
# (16, 209, 'TONYA', 'CHAPMAN')
# (8, 210, 'ELLA', 'OLIVER')
# (8, 211, 'STACEY', 'MONTGOMERY')
# (16, 212, 'WILMA', 'RICHARDS')
# (36, 213, 'GINA', 'WILLIAMSON')
# (12, 214, 'KRISTIN', 'JOHNSTON')
# (24, 215, 'JESSIE', 'BANKS')
# (20, 216, 'NATALIE', 'MEYER')
# (12, 217, 'AGNES', 'BISHOP')
# (12, 218, 'VERA', 'MCCOY')
# (8, 219, 'WILLIE', 'HOWELL')
# (4, 220, 'CHARLENE', 'ALVAREZ')
# (20, 221, 'BESSIE', 'MORRISON')
# (8, 222, 'DELORES', 'HANSEN')
# (8, 223, 'MELINDA', 'FERNANDEZ')
# (12, 224, 'PEARL', 'GARZA')
# (4, 225, 'ARLENE', 'HARVEY')
# (8, 226, 'MAUREEN', 'LITTLE')
# (16, 227, 'COLLEEN', 'BURTON')
# (16, 228, 'ALLISON', 'STANLEY')
# (16, 229, 'TAMARA', 'NGUYEN')
# (24, 230, 'JOY', 'GEORGE')
# (4, 231, 'GEORGIA', 'JACOBS')
# (8, 232, 'CONSTANCE', 'REID')
# (16, 233, 'LILLIE', 'KIM')
# (32, 234, 'CLAUDIA', 'FULLER')
# (8, 235, 'JACKIE', 'LYNCH')
# (32, 236, 'MARCIA', 'DEAN')
# (20, 237, 'TANYA', 'GILBERT')
# (12, 238, 'NELLIE', 'GARRETT')
# (20, 239, 'MINNIE', 'ROMERO')
# (12, 240, 'MARLENE', 'WELCH')
# (20, 241, 'HEIDI', 'LARSON')
# (24, 242, 'GLENDA', 'FRAZIER')
# (12, 243, 'LYDIA', 'BURKE')
# (12, 244, 'VIOLA', 'HANSON')
# (12, 245, 'COURTNEY', 'DAY')
# (20, 246, 'MARIAN', 'MENDOZA')
# (4, 247, 'STELLA', 'MORENO')
# (8, 248, 'CAROLINE', 'BOWMAN')
# (20, 249, 'DORA', 'MEDINA')
# (4, 250, 'JO', 'FOWLER')
# (12, 251, 'VICKIE', 'BREWER')
# (12, 252, 'MATTIE', 'HOFFMAN')
# (24, 253, 'TERRY', 'CARLSON')
# (20, 254, 'MAXINE', 'SILVA')
# (16, 255, 'IRMA', 'PEARSON')
# (28, 256, 'MABEL', 'HOLLAND')
# (8, 257, 'MARSHA', 'DOUGLAS')
# (12, 258, 'MYRTLE', 'FLEMING')
# (16, 259, 'LENA', 'JENSEN')
# (32, 260, 'CHRISTY', 'VARGAS')
# (24, 261, 'DEANNA', 'BYRD')
# (16, 262, 'PATSY', 'DAVIDSON')
# (8, 263, 'HILDA', 'HOPKINS')
# (16, 264, 'GWENDOLYN', 'MAY')
# (12, 265, 'JENNIE', 'TERRY')
# (16, 266, 'NORA', 'HERRERA')
# (36, 267, 'MARGIE', 'WADE')
# (32, 268, 'NINA', 'SOTO')
# (12, 269, 'CASSANDRA', 'WALTERS')
# (16, 270, 'LEAH', 'CURTIS')
# (4, 271, 'PENNY', 'NEAL')
# (12, 272, 'KAY', 'CALDWELL')
# (20, 273, 'PRISCILLA', 'LOWE')
# (8, 274, 'NAOMI', 'JENNINGS')
# (16, 275, 'CAROLE', 'BARNETT')
# (12, 276, 'BRANDY', 'GRAVES')
# (28, 277, 'OLGA', 'JIMENEZ')
# (16, 278, 'BILLIE', 'HORTON')
# (20, 279, 'DIANNE', 'SHELTON')
# (12, 280, 'TRACEY', 'BARRETT')
# (8, 281, 'LEONA', 'OBRIEN')
# (16, 282, 'JENNY', 'CASTRO')
# (20, 283, 'FELICIA', 'SUTTON')
# (12, 284, 'SONIA', 'GREGORY')
# (12, 285, 'MIRIAM', 'MCKINNEY')
# (8, 286, 'VELMA', 'LUCAS')
# (16, 287, 'BECKY', 'MILES')
# (4, 288, 'BOBBIE', 'CRAIG')
# (24, 289, 'VIOLET', 'RODRIQUEZ')
# (20, 290, 'KRISTINA', 'CHAMBERS')
# (12, 291, 'TONI', 'HOLT')
# (16, 292, 'MISTY', 'LAMBERT')
# (28, 293, 'MAE', 'FLETCHER')
# (8, 294, 'SHELLY', 'WATTS')
# (36, 295, 'DAISY', 'BATES')
# (12, 296, 'RAMONA', 'HALE')
# (20, 297, 'SHERRI', 'RHODES')
# (16, 298, 'ERIKA', 'PENA')
# (28, 299, 'JAMES', 'GANNON')
# (8, 300, 'JOHN', 'FARNSWORTH')
# (12, 301, 'ROBERT', 'BAUGHMAN')
# (4, 302, 'MICHAEL', 'SILVERMAN')
# (16, 303, 'WILLIAM', 'SATTERFIELD')
# (16, 304, 'DAVID', 'ROYAL')
# (16, 305, 'RICHARD', 'MCCRARY')
# (8, 306, 'CHARLES', 'KOWALSKI')
# (24, 307, 'JOSEPH', 'JOY')
# (20, 308, 'THOMAS', 'GRIGSBY')
# (16, 309, 'CHRISTOPHER', 'GRECO')
# (24, 310, 'DANIEL', 'CABRAL')
# (12, 311, 'PAUL', 'TROUT')
# (8, 312, 'MARK', 'RINEHART')
# (12, 313, 'DONALD', 'MAHON')
# (8, 314, 'GEORGE', 'LINTON')
# (4, 315, 'KENNETH', 'GOODEN')
# (28, 316, 'STEVEN', 'CURLEY')
# (12, 317, 'EDWARD', 'BAUGH')
# (16, 318, 'BRIAN', 'WYMAN')
# (24, 319, 'RONALD', 'WEINER')
# (20, 320, 'ANTHONY', 'SCHWAB')
# (8, 321, 'KEVIN', 'SCHULER')
# (28, 322, 'JASON', 'MORRISSEY')
# (12, 323, 'MATTHEW', 'MAHAN')
# (8, 324, 'GARY', 'COY')
# (12, 325, 'TIMOTHY', 'BUNN')
# (16, 326, 'JOSE', 'ANDREW')
# (24, 327, 'LARRY', 'THRASHER')
# (20, 328, 'JEFFREY', 'SPEAR')
# (36, 329, 'FRANK', 'WAGGONER')
# (20, 330, 'SCOTT', 'SHELLEY')
# (12, 331, 'ERIC', 'ROBERT')
# (16, 333, 'ANDREW', 'PURDY')
# (12, 334, 'RAYMOND', 'MCWHORTER')
# (4, 335, 'GREGORY', 'MAULDIN')
# (32, 336, 'JOSHUA', 'MARK')
# (8, 337, 'JERRY', 'JORDON')
# (28, 338, 'DENNIS', 'GILMAN')
# (20, 339, 'WALTER', 'PERRYMAN')
# (32, 340, 'PATRICK', 'NEWSOM')
# (28, 341, 'PETER', 'MENARD')
# (12, 342, 'HAROLD', 'MARTINO')
# (28, 343, 'DOUGLAS', 'GRAF')
# (12, 344, 'HENRY', 'BILLINGSLEY')
# (16, 345, 'CARL', 'ARTIS')
# (12, 346, 'ARTHUR', 'SIMPKINS')
# (20, 347, 'RYAN', 'SALISBURY')
# (12, 348, 'ROGER', 'QUINTANILLA')
# (16, 349, 'JOE', 'GILLILAND')
# (16, 350, 'JUAN', 'FRALEY')
# (12, 351, 'JACK', 'FOUST')
# (20, 352, 'ALBERT', 'CROUSE')
# (12, 353, 'JONATHAN', 'SCARBOROUGH')
# (16, 354, 'JUSTIN', 'NGO')
# (8, 355, 'TERRY', 'GRISSOM')
# (12, 356, 'GERALD', 'FULTZ')
# (16, 357, 'KEITH', 'RICO')
# (24, 358, 'SAMUEL', 'MARLOW')
# (16, 359, 'WILLIE', 'MARKHAM')
# (16, 360, 'RALPH', 'MADRIGAL')
# (16, 361, 'LAWRENCE', 'LAWTON')
# (20, 362, 'NICHOLAS', 'BARFIELD')
# (20, 363, 'ROY', 'WHITING')
# (20, 364, 'BENJAMIN', 'VARNEY')
# (20, 365, 'BRUCE', 'SCHWARZ')
# (8, 366, 'BRANDON', 'HUEY')
# (4, 367, 'ADAM', 'GOOCH')
# (24, 368, 'HARRY', 'ARCE')
# (4, 369, 'FRED', 'WHEAT')
# (4, 370, 'WAYNE', 'TRUONG')
# (28, 371, 'BILLY', 'POULIN')
# (12, 372, 'STEVE', 'MACKENZIE')
# (8, 373, 'LOUIS', 'LEONE')
# (16, 374, 'JEREMY', 'HURTADO')
# (12, 375, 'AARON', 'SELBY')
# (8, 376, 'RANDY', 'GAITHER')
# (20, 377, 'HOWARD', 'FORTNER')
# (16, 378, 'EUGENE', 'CULPEPPER')
# (12, 379, 'CARLOS', 'COUGHLIN')
# (32, 380, 'RUSSELL', 'BRINSON')
# (20, 381, 'BOBBY', 'BOUDREAU')
# (20, 382, 'VICTOR', 'BARKLEY')
# (24, 383, 'MARTIN', 'BALES')
# (28, 384, 'ERNEST', 'STEPP')
# (12, 385, 'PHILLIP', 'HOLM')
# (20, 386, 'TODD', 'TAN')
# (24, 387, 'JESSE', 'SCHILLING')
# (20, 388, 'CRAIG', 'MORRELL')
# (12, 389, 'ALAN', 'KAHN')
# (20, 390, 'SHAWN', 'HEATON')
# (20, 391, 'CLARENCE', 'GAMEZ')
# (16, 392, 'SEAN', 'DOUGLASS')
# (20, 393, 'PHILIP', 'CAUSEY')
# (4, 394, 'CHRIS', 'BROTHERS')
# (24, 395, 'JOHNNY', 'TURPIN')
# (12, 396, 'EARL', 'SHANKS')
# (8, 397, 'JIMMY', 'SCHRADER')
# (12, 398, 'ANTONIO', 'MEEK')
# (8, 399, 'DANNY', 'ISOM')
# (12, 400, 'BRYAN', 'HARDISON')
# (12, 402, 'LUIS', 'YANEZ')
# (24, 403, 'MIKE', 'WAY')
# (16, 404, 'STANLEY', 'SCROGGINS')
# (24, 405, 'LEONARD', 'SCHOFIELD')
# (28, 406, 'NATHAN', 'RUNYON')
# (8, 407, 'DALE', 'RATCLIFF')
# (12, 408, 'MANUEL', 'MURRELL')
# (8, 409, 'RODNEY', 'MOELLER')
# (24, 410, 'CURTIS', 'IRBY')
# (12, 411, 'NORMAN', 'CURRIER')
# (4, 412, 'ALLEN', 'BUTTERFIELD')
# (8, 413, 'MARVIN', 'YEE')
# (12, 414, 'VINCENT', 'RALSTON')
# (8, 415, 'GLENN', 'PULLEN')
# (20, 416, 'JEFFERY', 'PINSON')
# (4, 417, 'TRAVIS', 'ESTEP')
# (12, 418, 'JEFF', 'EAST')
# (4, 419, 'CHAD', 'CARBONE')
# (12, 420, 'JACOB', 'LANCE')
# (12, 421, 'LEE', 'HAWKS')
# (16, 422, 'MELVIN', 'ELLINGTON')
# (20, 423, 'ALFRED', 'CASILLAS')
# (12, 424, 'KYLE', 'SPURLOCK')
# (4, 425, 'FRANCIS', 'SIKES')
# (20, 426, 'BRADLEY', 'MOTLEY')
# (20, 427, 'JESUS', 'MCCARTNEY')
# (20, 428, 'HERBERT', 'KRUGER')
# (16, 429, 'FREDERICK', 'ISBELL')
# (24, 430, 'RAY', 'HOULE')
# (28, 431, 'JOEL', 'FRANCISCO')
# (12, 432, 'EDWIN', 'BURK')
# (28, 434, 'EDDIE', 'TOMLIN')
# (8, 435, 'RICKY', 'SHELBY')
# (4, 436, 'TROY', 'QUIGLEY')
# (12, 437, 'RANDALL', 'NEUMANN')
# (24, 438, 'BARRY', 'LOVELACE')
# (24, 439, 'ALEXANDER', 'FENNELL')
# (8, 441, 'MARIO', 'CHEATHAM')
# (16, 442, 'LEROY', 'BUSTAMANTE')
# (4, 443, 'FRANCISCO', 'SKIDMORE')
# (24, 444, 'MARCUS', 'HIDALGO')
# (24, 446, 'THEODORE', 'CULP')
# (16, 447, 'CLIFFORD', 'BOWENS')
# (20, 448, 'MIGUEL', 'BETANCOURT')
# (12, 449, 'OSCAR', 'AQUINO')
# (28, 450, 'JAY', 'ROBB')
# (28, 451, 'JIM', 'REA')
# (28, 452, 'TOM', 'MILNER')
# (12, 453, 'CALVIN', 'MARTEL')
# (40, 454, 'ALEX', 'GRESHAM')
# (16, 455, 'JON', 'WILES')
# (28, 456, 'RONNIE', 'RICKETTS')
# (36, 457, 'BILL', 'GAVIN')
# (8, 458, 'LLOYD', 'DOWD')
# (28, 459, 'TOMMY', 'COLLAZO')
# (4, 460, 'LEON', 'BOSTIC')
# (8, 461, 'DEREK', 'BLAKELY')
# (12, 462, 'WARREN', 'SHERROD')
# (16, 463, 'DARRELL', 'POWER')
# (8, 464, 'JEROME', 'KENYON')
# (16, 465, 'FLOYD', 'GANDY')
# (20, 466, 'LEO', 'EBERT')
# (16, 467, 'ALVIN', 'DELOACH')
# (24, 468, 'TIM', 'CARY')
# (8, 469, 'WESLEY', 'BULL')
# (12, 470, 'GORDON', 'ALLARD')
# (20, 471, 'DEAN', 'SAUER')
# (24, 472, 'GREG', 'ROBINS')
# (16, 473, 'JORGE', 'OLIVARES')
# (8, 474, 'DUSTIN', 'GILLETTE')
# (16, 476, 'DERRICK', 'BOURQUE')
# (16, 477, 'DAN', 'PAINE')
# (24, 478, 'LEWIS', 'LYMAN')
# (24, 479, 'ZACHARY', 'HITE')
# (8, 480, 'COREY', 'HAUSER')
# (16, 481, 'HERMAN', 'DEVORE')
# (8, 482, 'MAURICE', 'CRAWLEY')
# (12, 483, 'VERNON', 'CHAPA')
# (16, 484, 'ROBERTO', 'VU')
# (8, 485, 'CLYDE', 'TOBIAS')
# (16, 486, 'GLEN', 'TALBERT')
# (4, 487, 'HECTOR', 'POINDEXTER')
# (8, 488, 'SHANE', 'MILLARD')
# (16, 489, 'RICARDO', 'MEADOR')
# (4, 490, 'SAM', 'MCDUFFIE')
# (28, 491, 'RICK', 'MATTOX')
# (16, 492, 'LESTER', 'KRAUS')
# (16, 493, 'BRENT', 'HARKINS')
# (4, 494, 'RAMON', 'CHOATE')
# (16, 495, 'CHARLIE', 'BESS')
# (4, 496, 'TYLER', 'WREN')
# (16, 497, 'GILBERT', 'SLEDGE')
# (24, 498, 'GENE', 'SANBORN')
# (16, 499, 'MARC', 'OUTLAW')
# (20, 500, 'REGINALD', 'KINDER')
# (8, 501, 'RUBEN', 'GEARY')
# (12, 502, 'BRETT', 'CORNWELL')
# (12, 503, 'ANGEL', 'BARCLAY')
# (8, 504, 'NATHANIEL', 'ADAM')
# (16, 505, 'RAFAEL', 'ABNEY')
# (20, 506, 'LESLIE', 'SEWARD')
# (12, 507, 'EDGAR', 'RHOADS')
# (4, 508, 'MILTON', 'HOWLAND')
# (8, 509, 'RAUL', 'FORTIER')
# (32, 510, 'BEN', 'EASTER')
# (16, 511, 'CHESTER', 'BENNER')
# (12, 512, 'CECIL', 'VINES')
# (12, 513, 'DUANE', 'TUBBS')
# (24, 514, 'FRANKLIN', 'TROUTMAN')
# (24, 515, 'ANDRE', 'RAPP')
# (24, 516, 'ELMER', 'NOE')
# (20, 517, 'BRAD', 'MCCURDY')
# (8, 518, 'GABRIEL', 'HARDER')
# (12, 519, 'RON', 'DELUCA')
# (12, 520, 'MITCHELL', 'WESTMORELAND')
# (8, 521, 'ROLAND', 'SOUTH')
# (16, 522, 'ARNOLD', 'HAVENS')
# (16, 523, 'HARVEY', 'GUAJARDO')
# (12, 524, 'JARED', 'ELY')
# (4, 525, 'ADRIAN', 'CLARY')
# (36, 526, 'KARL', 'SEAL')
# (16, 527, 'CORY', 'MEEHAN')
# (8, 528, 'CLAUDE', 'HERZOG')
# (12, 529, 'ERIK', 'GUILLEN')
# (12, 530, 'DARRYL', 'ASHCRAFT')
# (4, 531, 'JAMIE', 'WAUGH')
# (8, 532, 'NEIL', 'RENNER')
# (24, 533, 'JESSIE', 'MILAM')
# (20, 534, 'CHRISTIAN', 'JUNG')
# (8, 535, 'JAVIER', 'ELROD')
# (12, 536, 'FERNANDO', 'CHURCHILL')
# (16, 537, 'CLINTON', 'BUFORD')
# (16, 538, 'TED', 'BREAUX')
# (12, 539, 'MATHEW', 'BOLIN')
# (20, 540, 'TYRONE', 'ASHER')
# (8, 541, 'DARREN', 'WINDHAM')
# (8, 542, 'LONNIE', 'TIRADO')
# (20, 543, 'LANCE', 'PEMBERTON')
# (16, 544, 'CODY', 'NOLEN')
# (4, 545, 'JULIO', 'NOLAND')
# (16, 546, 'KELLY', 'KNOTT')
# (4, 547, 'KURT', 'EMMONS')
# (12, 548, 'ALLAN', 'CORNISH')
# (4, 549, 'NELSON', 'CHRISTENSON')
# (24, 550, 'GUY', 'BROWNLEE')
# (8, 551, 'CLAYTON', 'BARBEE')
# (8, 552, 'HUGH', 'WALDROP')
# (12, 553, 'MAX', 'PITT')
# (16, 554, 'DWAYNE', 'OLVERA')
# (4, 555, 'DWIGHT', 'LOMBARDI')
# (20, 556, 'ARMANDO', 'GRUBER')
# (12, 557, 'FELIX', 'GAFFNEY')
# (20, 558, 'JIMMIE', 'EGGLESTON')
# (16, 559, 'EVERETT', 'BANDA')
# (8, 560, 'JORDAN', 'ARCHULETA')
# (36, 561, 'IAN', 'STILL')
# (16, 562, 'WALLACE', 'SLONE')
# (8, 563, 'KEN', 'PREWITT')
# (4, 564, 'BOB', 'PFEIFFER')
# (12, 565, 'JAIME', 'NETTLES')
# (16, 566, 'CASEY', 'MENA')
# (8, 567, 'ALFREDO', 'MCADAMS')
# (20, 568, 'ALBERTO', 'HENNING')
# (8, 569, 'DAVE', 'GARDINER')
# (28, 570, 'IVAN', 'CROMWELL')
# (24, 571, 'JOHNNIE', 'CHISHOLM')
# (12, 572, 'SIDNEY', 'BURLESON')
# (16, 573, 'BYRON', 'BOX')
# (20, 574, 'JULIAN', 'VEST')
# (12, 575, 'ISAAC', 'OGLESBY')
# (28, 576, 'MORRIS', 'MCCARTER')
# (12, 577, 'CLIFTON', 'MALCOLM')
# (12, 578, 'WILLARD', 'LUMPKIN')
# (12, 579, 'DARYL', 'LARUE')
# (4, 580, 'ROSS', 'GREY')
# (12, 581, 'VIRGIL', 'WOFFORD')
# (12, 582, 'ANDY', 'VANHORN')
# (24, 583, 'MARSHALL', 'THORN')
# (8, 584, 'SALVADOR', 'TEEL')
# (16, 585, 'PERRY', 'SWAFFORD')
# (8, 586, 'KIRK', 'STCLAIR')
# (16, 587, 'SERGIO', 'STANFIELD')
# (20, 588, 'MARION', 'OCAMPO')
# (20, 589, 'TRACY', 'HERRMANN')
# (20, 590, 'SETH', 'HANNON')
# (12, 591, 'KENT', 'ARSENAULT')
# (20, 592, 'TERRANCE', 'ROUSH')
# (16, 593, 'RENE', 'MCALISTER')
# (24, 594, 'EDUARDO', 'HIATT')
# (8, 595, 'TERRENCE', 'GUNDERSON')
# (8, 596, 'ENRIQUE', 'FORSYTHE')
# (12, 597, 'FREDDIE', 'DUGGAN')
# (4, 598, 'WADE', 'DELVALLE')
# (16, 599, 'AUSTIN', 'CINTRON')
